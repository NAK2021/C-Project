-- %% [markdown]
-- # [dbo].[Academic_Affair]

-- %%
USE [DBManager2]
GO

-- %%
/****** Object:  Table [dbo].[Academic_Affair]    Script Date: 12/10/2023 10:47:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Academic_Affair](
	[id] [nvarchar](100) NOT NULL,
	[username] [nvarchar](50) NULL,
	[name_] [nvarchar](50) NULL,
	[dob] [nvarchar](20) NULL,
	[phone_num] [nvarchar](15) NULL,
	[department_id] [nvarchar](10) NULL,
	[picture] [image] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Admin]

-- %%
/****** Object:  Table [dbo].[Admin]    Script Date: 12/10/2023 10:47:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Admin](
	[id] [nvarchar](100) NOT NULL,
	[usename] [nvarchar](50) NULL,
	[name_] [nvarchar](50) NULL,
	[dob] [nvarchar](20) NULL,
	[phone_num] [nvarchar](15) NULL,
	[picture] [image] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Class]

-- %%
/****** Object:  Table [dbo].[Class]    Script Date: 12/10/2023 10:47:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Class](
	[class_id] [int] NOT NULL,
	[date_start] [nvarchar](20) NULL,
	[date_end] [nvarchar](20) NULL,
	[room] [nvarchar](50) NULL,
	[capacity] [int] NULL,
	[days_] [nvarchar](20) NULL,
	[section_start] [time](7) NULL,
	[section_end] [time](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[class_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Department]

-- %%
/****** Object:  Table [dbo].[Department]    Script Date: 12/10/2023 10:47:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Department](
	[department_id] [nvarchar](10) NOT NULL,
	[department_name] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[department_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Lecture]

-- %%
/****** Object:  Table [dbo].[Lecture]    Script Date: 12/10/2023 10:47:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Lecture](
	[id] [nvarchar](100) NOT NULL,
	[email] [varchar](50) NULL,
	[name_] [nvarchar](50) NULL,
	[dob] [nvarchar](20) NULL,
	[phone_num] [nvarchar](15) NULL,
	[department_id] [nvarchar](20) NULL,
	[status_] [nvarchar](20) NULL,
	[Teaching_Experience] [int] NULL,
	[Academic_rank] [nvarchar](20) NULL,
	[picture] [image] NULL,
	[assigned_subjects] [nvarchar](200) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LectureRegisClass]

-- %%
/****** Object:  Table [dbo].[LectureRegisClass]    Script Date: 12/10/2023 10:47:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LectureRegisClass](
	[id] [nvarchar](100) NOT NULL,
	[class_id] [int] NOT NULL,
	[date_register] [nvarchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC,
	[class_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LectureVio]

-- %%
/****** Object:  Table [dbo].[LectureVio]    Script Date: 12/10/2023 10:47:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LectureVio](
	[id] [nvarchar](100) NOT NULL,
	[rules_id] [int] NOT NULL,
	[status_] [nvarchar](50) NULL,
	[date_] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC,
	[rules_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OpenClass]

-- %%
/****** Object:  Table [dbo].[OpenClass]    Script Date: 12/10/2023 10:47:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OpenClass](
	[course_id] [nvarchar](10) NOT NULL,
	[class_id] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[course_id] ASC,
	[class_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Student]

-- %%
/****** Object:  Table [dbo].[Student]    Script Date: 12/10/2023 10:47:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Student](
	[id] [nvarchar](100) NOT NULL,
	[name_] [nvarchar](50) NULL,
	[school_year] [nvarchar](50) NULL,
	[dob] [nvarchar](50) NULL,
	[phone_num] [nvarchar](15) NULL,
	[department_id] [nvarchar](10) NULL,
	[tot_cred] [int] NULL,
	[status_] [nvarchar](50) NULL,
	[picture] [image] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[StudentRegisClass]

-- %%
/****** Object:  Table [dbo].[StudentRegisClass]    Script Date: 12/10/2023 10:47:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[StudentRegisClass](
	[id] [nvarchar](100) NOT NULL,
	[class_id] [int] NOT NULL,
	[date_register] [nvarchar](20) NULL,
	[status_] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC,
	[class_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[StudentVio]

-- %%
/****** Object:  Table [dbo].[StudentVio]    Script Date: 12/10/2023 10:47:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[StudentVio](
	[id] [nvarchar](100) NOT NULL,
	[rules_id] [int] NOT NULL,
	[status_] [nvarchar](50) NULL,
	[date_] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC,
	[rules_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Subject_]

-- %%
/****** Object:  Table [dbo].[Subject_]    Script Date: 12/10/2023 10:47:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Subject_](
	[course_id] [nvarchar](10) NOT NULL,
	[course_name] [nvarchar](50) NULL,
	[department_id] [nvarchar](10) NULL,
	[credits] [int] NULL,
	[cost] [numeric](18, 0) NULL,
PRIMARY KEY CLUSTERED 
(
	[course_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 12/10/2023 10:47:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[id] [nvarchar](100) NOT NULL,
	[password_] [nvarchar](50) NULL,
	[role_] [nvarchar](20) NULL,
	[pin] [nvarchar](6) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Violate]

-- %%
/****** Object:  Table [dbo].[Violate]    Script Date: 12/10/2023 10:47:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Violate](
	[rules_id] [int] NOT NULL,
	[rules_name] [nvarchar](50) NULL,
	[rules_punishment] [nvarchar](50) NULL,
	[object_] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[rules_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__Academic___depar__3D5E1FD2]

-- %%
ALTER TABLE [dbo].[Academic_Affair]  WITH CHECK ADD FOREIGN KEY([department_id])
REFERENCES [dbo].[Department] ([department_id])
GO

-- %% [markdown]
-- # [FK__Academic_Aff__id__3E52440B]

-- %%
ALTER TABLE [dbo].[Academic_Affair]  WITH CHECK ADD FOREIGN KEY([id])
REFERENCES [dbo].[Users] ([id])
GO

-- %% [markdown]
-- # [FK__Admin__phone_num__5FB337D6]

-- %%
ALTER TABLE [dbo].[Admin]  WITH CHECK ADD FOREIGN KEY([id])
REFERENCES [dbo].[Users] ([id])
GO

-- %% [markdown]
-- # [FK__Lecture__Academi__48CFD27E]

-- %%
ALTER TABLE [dbo].[Lecture]  WITH CHECK ADD FOREIGN KEY([id])
REFERENCES [dbo].[Users] ([id])
GO

-- %% [markdown]
-- # [FK__LectureRe__class__5629CD9C]

-- %%
ALTER TABLE [dbo].[LectureRegisClass]  WITH CHECK ADD FOREIGN KEY([class_id])
REFERENCES [dbo].[Class] ([class_id])
GO

-- %% [markdown]
-- # [FK__LectureRe__date___5535A963]

-- %%
ALTER TABLE [dbo].[LectureRegisClass]  WITH CHECK ADD FOREIGN KEY([id])
REFERENCES [dbo].[Lecture] ([id])
GO

-- %% [markdown]
-- # [FK__LectureVi__rules__4BAC3F29]

-- %%
ALTER TABLE [dbo].[LectureVio]  WITH CHECK ADD FOREIGN KEY([rules_id])
REFERENCES [dbo].[Violate] ([rules_id])
GO

-- %% [markdown]
-- # [FK__LectureVio__id__4CA06362]

-- %%
ALTER TABLE [dbo].[LectureVio]  WITH CHECK ADD FOREIGN KEY([id])
REFERENCES [dbo].[Lecture] ([id])
GO

-- %% [markdown]
-- # [FK__OpenClass__class__5BE2A6F2]

-- %%
ALTER TABLE [dbo].[OpenClass]  WITH CHECK ADD FOREIGN KEY([class_id])
REFERENCES [dbo].[Class] ([class_id])
GO

-- %% [markdown]
-- # [FK__OpenClass__cours__5CD6CB2B]

-- %%
ALTER TABLE [dbo].[OpenClass]  WITH CHECK ADD FOREIGN KEY([course_id])
REFERENCES [dbo].[Subject_] ([course_id])
GO

-- %% [markdown]
-- # [FK__Student__id__4222D4EF]

-- %%
ALTER TABLE [dbo].[Student]  WITH CHECK ADD FOREIGN KEY([id])
REFERENCES [dbo].[Users] ([id])
GO

-- %% [markdown]
-- # [FK__Student__status___412EB0B6]

-- %%
ALTER TABLE [dbo].[Student]  WITH CHECK ADD FOREIGN KEY([department_id])
REFERENCES [dbo].[Department] ([department_id])
GO

-- %% [markdown]
-- # [FK__StudentRe__class__52593CB8]

-- %%
ALTER TABLE [dbo].[StudentRegisClass]  WITH CHECK ADD FOREIGN KEY([class_id])
REFERENCES [dbo].[Class] ([class_id])
GO

-- %% [markdown]
-- # [FK__StudentRegis__id__5165187F]

-- %%
ALTER TABLE [dbo].[StudentRegisClass]  WITH CHECK ADD FOREIGN KEY([id])
REFERENCES [dbo].[Student] ([id])
GO

-- %% [markdown]
-- # [FK__StudentVi__date___44FF419A]

-- %%
ALTER TABLE [dbo].[StudentVio]  WITH CHECK ADD FOREIGN KEY([rules_id])
REFERENCES [dbo].[Violate] ([rules_id])
GO

-- %% [markdown]
-- # [FK__StudentVio__id__45F365D3]

-- %%
ALTER TABLE [dbo].[StudentVio]  WITH CHECK ADD FOREIGN KEY([id])
REFERENCES [dbo].[Student] ([id])
GO

-- %% [markdown]
-- # [FK__Subject___depart__59063A47]

-- %%
ALTER TABLE [dbo].[Subject_]  WITH CHECK ADD FOREIGN KEY([department_id])
REFERENCES [dbo].[Department] ([department_id])
GO
